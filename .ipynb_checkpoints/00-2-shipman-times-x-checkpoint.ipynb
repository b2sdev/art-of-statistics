# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("./data/00-2-shipman-times-x.csv")

# %%
plt.plot('Hour', 'Shipman', data=df)
plt.plot('Hour', 'Comparison', data=df)
plt.legend()
